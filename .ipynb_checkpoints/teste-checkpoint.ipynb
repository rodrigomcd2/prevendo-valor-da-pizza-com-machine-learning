# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ffran\workspace\prevendo valor da pizza com machine learning\pizzas.csv")


print(df.head())
# Out:
#    diametro  preco
# 0        20     50
# 1        22     55
# 2        24     60
# 3        26     65
# 4        28     70

# %%
df.plot(kind="scatter", x ="diametro",y="preco")
# Out:
# <Axes: xlabel='diametro', ylabel='preco'>

# %%
from sklearn import linear_model

modelo = linear_model.LinearRegression()
x = df[["diametro"]]
y = df[["preco"]]

modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
print(modelo.predict([[23]])[0][0])
# Out:
# 57.49999999999999
# C:\Users\ffran\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
